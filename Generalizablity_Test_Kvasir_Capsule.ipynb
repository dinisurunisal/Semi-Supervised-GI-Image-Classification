# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !nvidia-smi
# Out:
# Wed May 18 10:28:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Main Libraries

# %%
pip install -q -U tensorflow-addons
# Out:
#      |████████████████████████████████| 1.1 MB 18.2 MB/s

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import pathlib
import matplotlib.pyplot as plt
import datetime
import math
import itertools 
import pickle
import time
import os
import sys
import shutil
import keras
import glob
import cv2
import random
import textwrap
import scipy.ndimage as ndimage
import seaborn as sns

print("TF version:", tf.__version__)

from sklearn.model_selection import train_test_split
from math import ceil, floor
from pathlib import Path
from tqdm import tqdm
from sklearn import metrics
from tqdm.notebook import tqdm
from IPython.display import clear_output
from PIL import Image, ImageDraw, ImageFont
# Out:
# TF version: 2.8.0

# %% [markdown]
# ##Setup Colab

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ##Unzip Datasets

# %%
# !unzip "/content/drive/My Drive/ColabNotebooks/Datasets/Kvasir-capsule-dataset.zip"
# Out:
# Archive:  /content/drive/My Drive/ColabNotebooks/Datasets/Kvasir-capsule-dataset.zip
# replace Kvasir-capsule Dataset/Ampulla of vater/eb0203196e284797_1157.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# ##Initialize

# %%
labeled_data_root = pathlib.Path('/content/Kvasir-capsule Dataset')
# unlab_data_root = pathlib.Path('/content/unlabeled-images')

# Primary directory
record_dir = "./records/{}".format("labelled_model")
pathlib.Path(record_dir).mkdir(parents=True, exist_ok=True) # record_directory

cache_dir = "./cache"
pathlib.Path(cache_dir).mkdir(parents=True, exist_ok=True) # cache directory

# %% [markdown]
# ##Split Dataset

# %%
def split_dataset():

    train_split = float(0.7)
    test_split = float(0.7)+float(0.2)
    random.seed(2800)
    
    # listdir() returns a list containing the names of the entries in the directory
    class_names = os.listdir(labeled_data_root)
    image_folders = [os.path.join(labeled_data_root, class_name) for class_name in class_names]
    
    num_samples = len(list(Path(labeled_data_root).glob('*/*')))

    train_folders = [os.path.join('labeled_data', 'train', name) for name in class_names]
    test_folders = [os.path.join('labeled_data', 'test', name) for name in class_names]
    val_folders = [os.path.join('labeled_data', 'val', name) for name in class_names]

    for folder in train_folders:
      Path(folder).mkdir(parents=True, exist_ok=True)

    for folder in test_folders:
      Path(folder).mkdir(parents=True, exist_ok=True)
                              
    for folder in val_folders:
      Path(folder).mkdir(parents=True, exist_ok=True)

    tqdm_img = tqdm(total=num_samples, desc='Images', position=0)

    # split all the classes equally to test, train and val
    for idx, directory in enumerate(image_folders):

        random.seed(2800)
        imagenames = os.listdir(directory)
        imagenames.sort() # make sure that the image filenames have a fixed order before shuffling
        random.shuffle(imagenames) # shuffles the ordering of image filenames (deterministic given the chosen seed)
        num_samples = len(imagenames)

        imagenames = np.array(imagenames)
        imagenames_split = np.split(imagenames, [floor(num_samples*train_split), floor(num_samples*test_split)])
        
        dataset = {'train': imagenames_split[0],
                   'test': imagenames_split[1],
                   'val': imagenames_split[2]}

        for split in dataset:
            output = os.path.join('labeled_data', split, directory.split("/")[-1])
            for filename in dataset[split]:
                filename = os.path.join(directory, filename)
                image_resize(filename, output)
                tqdm_img.update(1)

# %%
def image_resize(filename, output_dir):
    image = cv2.imread(filename, cv2.IMREAD_UNCHANGED)
    image = cv2.resize(image, (128, 128), interpolation=cv2.INTER_LINEAR)
    path = os.path.join(output_dir, filename.split('/')[-1])
    cv2.imwrite(path, image) # Save the image in the output directory

# %%
split_dataset()
# Out:
# Images:   0%|          | 0/47238 [00:00<?, ?it/s]

# %% [markdown]
# ##Build and form the train, test and val datasets

# %%
BATCH_SIZE = 8
CLASS_NAMES = None
NUMBER_CLASSES = 0
DATASET_SIZE_TRAIN = None
DATASET_SIZE_TEST = None
DATASET_SIZE_VAL = None
DATASET_SIZE_UNLAB = None
STEPS_TRAIN = None
STEPS_TEST = None
STEPS_VAL = None
RAW_TRAIN_DATASET = None
AUTOTUNE = tf.data.experimental.AUTOTUNE

# function to load input image, preprocess it and get label
def load_label_images(image_path):
    # read the image from database, decode it, convert the data type to
	  # floating point, and then resize it
    image_raw = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image_raw, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [128, 128])

    # parse the class label from the file path
    str_targets = tf.strings.split(image_path, os.path.sep)[-2]
    label_integer = tf.reduce_min(tf.where(tf.equal(str_targets, CLASS_NAMES)))
    label = tf.dtypes.cast(label_integer, tf.int32)

    return image, label

def build_datasets():

    global CLASS_NAMES
    global NUMBER_CLASSES
    global DATASET_SIZE_TRAIN
    global DATASET_SIZE_TEST
    global DATASET_SIZE_VAL
    global STEPS_TRAIN
    global STEPS_TEST
    global STEPS_VAL
    global RAW_TRAIN_DATASET

    labeled_data_root = pathlib.Path('/content/labeled_data')
    np.random.seed(seed=2800)

    class_names = np.array([item.name for item in labeled_data_root.glob('train/*')])

    CLASS_NAMES = class_names
    NUMBER_CLASSES = len(class_names)

    model_class_names = list(class_names)
    handle = open(record_dir+"/model_class_names.pkl", 'wb')
    pickle.dump(model_class_names, handle)
    
    dataset = {'train': str(labeled_data_root/'train'/'*/*.*g'),
          'test': str(labeled_data_root/'test'/'*/*.*g'),
          'val': str(labeled_data_root/'val'/'*/*.*g')}

    DATASET_SIZE_TRAIN = len(list(glob.glob(dataset["train"])))
    DATASET_SIZE_TEST = len(list(glob.glob(dataset["test"])))
    DATASET_SIZE_VAL = len(list(glob.glob(dataset["val"])))
    
    for split in dataset:
        dataset[split] = tf.data.Dataset.list_files(dataset[split],
                                    shuffle=True,
                                    seed=tf.constant(2800, tf.int64)
                                    )
    
    # Map labels with the images from tf.dataset to create "train", "test", "val" datasets
    for split in dataset:
        dataset[split] = dataset[split].map(load_label_images, num_parallel_calls=AUTOTUNE)
    
    RAW_TRAIN_DATASET = dataset["train"] # Clean dataset of the "train" split
    
    print("[INFO] loading the dataset...")

    # training dataset split will go through a resample, suffle, repeat, data augment,
    # and prefetched phase
    dataset["train"] = resample(dataset["train"])
    dataset["train"] = (
      dataset["train"]
      .shuffle(buffer_size=3000, seed=tf.constant(2800, tf.int64))
      .repeat()
      .map(dataset_augmentation(), num_parallel_calls=AUTOTUNE)
      .batch(BATCH_SIZE, drop_remainder=False)
      .prefetch(buffer_size=AUTOTUNE)
    )

    # testing dataset split will go through a caching, suffle, repeat,
    # and prefetched phase
    cache_string = "{}/{}_{}".format(cache_dir, 128, "test")
    dataset["test"] = (
      dataset["test"]
      .cache(cache_string)
      .shuffle(buffer_size=3000, seed=tf.constant(2800, tf.int64))
      .repeat()
      .batch(BATCH_SIZE, drop_remainder=False)
      .prefetch(buffer_size=AUTOTUNE)
    )

    # testing dataset split will go through a caching, suffle, repeat,
    # and prefetched phase
    cache_string = "{}/{}_{}".format(cache_dir, 128, "val")
    dataset["val"] = (
      dataset["val"]
      .cache(cache_string)
      .shuffle(buffer_size=3000, seed=tf.constant(2800, tf.int64))
      .repeat()
      .batch(BATCH_SIZE, drop_remainder=False)
      .prefetch(buffer_size=AUTOTUNE)
    )

    print("[INFO] train, test and val datasets created")

    STEPS_TRAIN = DATASET_SIZE_TRAIN//BATCH_SIZE
    STEPS_TEST = DATASET_SIZE_TEST//BATCH_SIZE
    STEPS_VAL = DATASET_SIZE_VAL//BATCH_SIZE
    
    return dataset

# %%
def count_class_samples(dataset, num_classes):
    count = np.zeros(num_classes) # returns a new array with zeros according to the class count
    for img, lab in dataset:
        count[lab] += 1
    return count

# %% [markdown]
# Resample Dataset

# %%
def resample(dataset):

    datasets = []
    cache_dir = './cache/{}_resampled_{}/'.format(128, 'train')
    pathlib.Path(cache_dir).mkdir(parents=True, exist_ok=True) # create cache directory
    
    for i in range(NUMBER_CLASSES): # NUMBER_CLASSES = 23
        data = dataset.filter(lambda img, lab: lab==i)
        data = data.cache(cache_dir+'{}_dataset'.format(i))
        
        data = data.repeat()
        datasets.append(data)
    
    target_dist = [ 1.0/NUMBER_CLASSES ] * NUMBER_CLASSES
    balanced_dataset = tf.data.experimental.sample_from_datasets(datasets, weights=target_dist, seed=2800)
    
    return balanced_dataset

# %% [markdown]
# Data Augmentation

# %%
def dataset_augmentation():

    tf.random.set_seed(2800) # global seed
    
    def image_augment(image, label):

        degree = tf.random.normal([])*360
        image = tfa.image.rotate(image, degree * math.pi / 180, interpolation='BILINEAR')
        image = tf.image.resize_with_crop_or_pad(image, 138, 138)
        image = tf.image.random_crop(image, (128, 128, 3), seed=2800)
        image = tf.image.random_brightness(image, max_delta=0.2, seed=2800)
        image = tf.image.random_saturation(image, lower=0.5, upper=1.5, seed=2800)
        # image = tf.image.random_contrast(image, lower=0.5, upper=1.5, seed=2800)
        # image = tf.image.random_hue(image, max_delta=0.2, seed=2800)
        image = tf.image.random_flip_left_right(image, seed=2800)
        image = tf.image.random_flip_up_down(image, seed=2800)


        # noise = tf.random.normal((128, 128, 3), mean=0.0, stddev=1.0, dtype=tf.float32)
        # image = tf.add(image, noise)
        # The random_* ops do not necessarily clamp.
        # Here it clip tensors value to min 0 and max 1
        image = tf.clip_by_value(image, 0.0, 1.0)
        return image, label
    
    return image_augment

# %%
dataset = build_datasets()
# Out:
# [INFO] loading the dataset...
# WARNING:tensorflow:From <ipython-input-15-8b47589df911>:15: sample_from_datasets_v2 (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.sample_from_datasets(...)`.
# [INFO] train, test and val datasets created

# %%
datasets_bin = [count_class_samples( RAW_TRAIN_DATASET, NUMBER_CLASSES)]
dataset["mix_train"] = RAW_TRAIN_DATASET

# %% [markdown]
# ##Define the model used for labelled data

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, GlobalMaxPool2D, Multiply, Concatenate, Input, Dropout, ZeroPadding2D, Flatten, BatchNormalization
from tensorflow.keras import backend as K
from keras.layers import concatenate

def create_hybrid_model():
        
    inputs = Input(batch_shape=(None, None, None, 3))

    base_model1 = tf.keras.applications.inception_resnet_v2.InceptionResNetV2(
        weights='imagenet', 
        include_top=False, 
        input_shape=(128, 128, 3),
        input_tensor=inputs
    )

    base_model2 = tf.keras.applications.resnet50.ResNet50(
        weights='imagenet', 
        include_top=False, 
        input_shape=(128, 128, 3),
        input_tensor=inputs
    )
    
    for layer in base_model1.layers:
        layer._name = layer.name + str("_model_1")
    
    for layer in base_model2.layers:
        layer._name = layer.name + str("_model_2")

    print(base_model1.output.shape)
    print(base_model2.output.shape)

    out1 = base_model1.output
    out1 = ZeroPadding2D(((0,2), (0,2)))(out1)
    
    outputs = concatenate([out1, base_model2.output])

    z = GlobalAveragePooling2D()(outputs)
    z = Flatten()(z) # newly added
    z = Dropout(0.3)(z)  # to prevent overfitting
    # z = BatchNormalization(z)
    z = Dense(28, activation='relu')(z) # relu to overcome gradient decent problem 
    z = Dense(3584, activation='sigmoid')(z)
    z = Multiply()([outputs, z])
    z = GlobalAveragePooling2D()(z)
    z = Dense(NUMBER_CLASSES, activation="softmax")(z) # "Softmax" Activation layer for classification

    model = Model(inputs=inputs, outputs=z) 
    
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    
    model.summary()
    
    return model

# %%
model = create_hybrid_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 1s 0us/step
# 219070464/219055592 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# (None, None, None, 1536)
# (None, None, None, 2048)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1_model_1_model_2 (Input  [(None, None, None,  0          []
#  Layer)                          3)]
#
#  conv2d_model_1 (Conv2D)        (None, None, None,   864         ['input_1_model_1_model_2[0][0]']
#                                 32)
#
#  batch_normalization_model_1 (B  (None, None, None,   96         ['conv2d_model_1[0][0]']
#  atchNormalization)             32)
#
#  activation_model_1 (Activation  (None, None, None,   0          ['batch_normalization_model_1[0][
#  )                              32)                              0]']
#
#  conv2d_1_model_1 (Conv2D)      (None, None, None,   9216        ['activation_model_1[0][0]']
#                                 32)
#
#  batch_normalization_1_model_1   (None, None, None,   96         ['conv2d_1_model_1[0][0]']
#  (BatchNormalization)           32)
#
#  activation_1_model_1 (Activati  (None, None, None,   0          ['batch_normalization_1_model_1[0
#  on)                            32)                              ][0]']
#
#  conv2d_2_model_1 (Conv2D)      (None, None, None,   18432       ['activation_1_model_1[0][0]']
#                                 64)
#
#  batch_normalization_2_model_1   (None, None, None,   192        ['conv2d_2_model_1[0][0]']
#  (BatchNormalization)           64)
#
#  activation_2_model_1 (Activati  (None, None, None,   0          ['batch_normalization_2_model_1[0
#  on)                            64)                              ][0]']
#
#  max_pooling2d_model_1 (MaxPool  (None, None, None,   0          ['activation_2_model_1[0][0]']
#  ing2D)                         64)
#
#  conv2d_3_model_1 (Conv2D)      (None, None, None,   5120        ['max_pooling2d_model_1[0][0]']
#                                 80)
#
#  batch_normalization_3_model_1   (None, None, None,   240        ['conv2d_3_model_1[0][0]']
#  (BatchNormalization)           80)
#
#  activation_3_model_1 (Activati  (None, None, None,   0          ['batch_normalization_3_model_1[0
#  on)                            80)                              ][0]']
#
#  conv2d_4_model_1 (Conv2D)      (None, None, None,   138240      ['activation_3_model_1[0][0]']
#                                 192)
#
#  batch_normalization_4_model_1   (None, None, None,   576        ['conv2d_4_model_1[0][0]']
#  (BatchNormalization)           192)
#
#  activation_4_model_1 (Activati  (None, None, None,   0          ['batch_normalization_4_model_1[0
#  on)                            192)                             ][0]']
#
#  max_pooling2d_1_model_1 (MaxPo  (None, None, None,   0          ['activation_4_model_1[0][0]']
#  oling2D)                       192)
#
#  conv2d_8_model_1 (Conv2D)      (None, None, None,   12288       ['max_pooling2d_1_model_1[0][0]']
#                                 64)
#
#  batch_normalization_8_model_1   (None, None, None,   192        ['conv2d_8_model_1[0][0]']
#  (BatchNormalization)           64)
#
#  activation_8_model_1 (Activati  (None, None, None,   0          ['batch_normalization_8_model_1[0
#  on)                            64)                              ][0]']
#
#  conv2d_6_model_1 (Conv2D)      (None, None, None,   9216        ['max_pooling2d_1_model_1[0][0]']
#                                 48)
#
#  conv2d_9_model_1 (Conv2D)      (None, None, None,   55296       ['activation_8_model_1[0][0]']
#                                 96)
#
#  batch_normalization_6_model_1   (None, None, None,   144        ['conv2d_6_model_1[0][0]']
#  (BatchNormalization)           48)
#
#  batch_normalization_9_model_1   (None, None, None,   288        ['conv2d_9_model_1[0][0]']
#  (BatchNormalization)           96)
#
#  activation_6_model_1 (Activati  (None, None, None,   0          ['batch_normalization_6_model_1[0
#  on)                            48)                              ][0]']
#
#  activation_9_model_1 (Activati  (None, None, None,   0          ['batch_normalization_9_model_1[0
#  on)                            96)                              ][0]']
#
#  average_pooling2d_model_1 (Ave  (None, None, None,   0          ['max_pooling2d_1_model_1[0][0]']
#  ragePooling2D)                 192)
#
#  conv2d_5_model_1 (Conv2D)      (None, None, None,   18432       ['max_pooling2d_1_model_1[0][0]']
#                                 96)
#
#  conv2d_7_model_1 (Conv2D)      (None, None, None,   76800       ['activation_6_model_1[0][0]']
#                                 64)
#
#  conv2d_10_model_1 (Conv2D)     (None, None, None,   82944       ['activation_9_model_1[0][0]']
#                                 96)
#
#  conv2d_11_model_1 (Conv2D)     (None, None, None,   12288       ['average_pooling2d_model_1[0][0]
#                                 64)                              ']
#
#  batch_normalization_5_model_1   (None, None, None,   288        ['conv2d_5_model_1[0][0]']
#  (BatchNormalization)           96)
#
#  batch_normalization_7_model_1   (None, None, None,   192        ['conv2d_7_model_1[0][0]']
#  (BatchNormalization)           64)
#
#  batch_normalization_10_model_1  (None, None, None,   288        ['conv2d_10_model_1[0][0]']
#   (BatchNormalization)          96)
#
#  batch_normalization_11_model_1  (None, None, None,   192        ['conv2d_11_model_1[0][0]']
#   (BatchNormalization)          64)
#
#  activation_5_model_1 (Activati  (None, None, None,   0          ['batch_normalization_5_model_1[0
#  on)                            96)                              ][0]']
#
#  activation_7_model_1 (Activati  (None, None, None,   0          ['batch_normalization_7_model_1[0
#  on)                            64)                              ][0]']
#
#  activation_10_model_1 (Activat  (None, None, None,   0          ['batch_normalization_10_model_1[
#  ion)                           96)                              0][0]']
#
#  activation_11_model_1 (Activat  (None, None, None,   0          ['batch_normalization_11_model_1[
#  ion)                           64)                              0][0]']
#
#  mixed_5b_model_1 (Concatenate)  (None, None, None,   0          ['activation_5_model_1[0][0]',
#                                 320)                              'activation_7_model_1[0][0]',
#                                                                   'activation_10_model_1[0][0]',
#                                                                   'activation_11_model_1[0][0]']
#
#  conv2d_15_model_1 (Conv2D)     (None, None, None,   10240       ['mixed_5b_model_1[0][0]']
#                                 32)
#
#  batch_normalization_15_model_1  (None, None, None,   96         ['conv2d_15_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  activation_15_model_1 (Activat  (None, None, None,   0          ['batch_normalization_15_model_1[
#  ion)                           32)                              0][0]']
#
#  conv2d_13_model_1 (Conv2D)     (None, None, None,   10240       ['mixed_5b_model_1[0][0]']
#                                 32)
#
#  conv2d_16_model_1 (Conv2D)     (None, None, None,   13824       ['activation_15_model_1[0][0]']
#                                 48)
#
#  batch_normalization_13_model_1  (None, None, None,   96         ['conv2d_13_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_16_model_1  (None, None, None,   144        ['conv2d_16_model_1[0][0]']
#   (BatchNormalization)          48)
#
#  activation_13_model_1 (Activat  (None, None, None,   0          ['batch_normalization_13_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_16_model_1 (Activat  (None, None, None,   0          ['batch_normalization_16_model_1[
#  ion)                           48)                              0][0]']
#
#  conv2d_12_model_1 (Conv2D)     (None, None, None,   10240       ['mixed_5b_model_1[0][0]']
#                                 32)
#
#  conv2d_14_model_1 (Conv2D)     (None, None, None,   9216        ['activation_13_model_1[0][0]']
#                                 32)
#
#  conv2d_17_model_1 (Conv2D)     (None, None, None,   27648       ['activation_16_model_1[0][0]']
#                                 64)
#
#  batch_normalization_12_model_1  (None, None, None,   96         ['conv2d_12_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_14_model_1  (None, None, None,   96         ['conv2d_14_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_17_model_1  (None, None, None,   192        ['conv2d_17_model_1[0][0]']
#   (BatchNormalization)          64)
#
#  activation_12_model_1 (Activat  (None, None, None,   0          ['batch_normalization_12_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_14_model_1 (Activat  (None, None, None,   0          ['batch_normalization_14_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_17_model_1 (Activat  (None, None, None,   0          ['batch_normalization_17_model_1[
#  ion)                           64)                              0][0]']
#
#  block35_1_mixed_model_1 (Conca  (None, None, None,   0          ['activation_12_model_1[0][0]',
#  tenate)                        128)                              'activation_14_model_1[0][0]',
#                                                                   'activation_17_model_1[0][0]']
#
#  block35_1_conv_model_1 (Conv2D  (None, None, None,   41280      ['block35_1_mixed_model_1[0][0]']
#  )                              320)
#
#  block35_1_model_1 (Lambda)     (None, None, None,   0           ['mixed_5b_model_1[0][0]',
#                                 320)                              'block35_1_conv_model_1[0][0]']
#
#  block35_1_ac_model_1 (Activati  (None, None, None,   0          ['block35_1_model_1[0][0]']
#  on)                            320)
#
#  conv2d_21_model_1 (Conv2D)     (None, None, None,   10240       ['block35_1_ac_model_1[0][0]']
#                                 32)
#
#  batch_normalization_21_model_1  (None, None, None,   96         ['conv2d_21_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  activation_21_model_1 (Activat  (None, None, None,   0          ['batch_normalization_21_model_1[
#  ion)                           32)                              0][0]']
#
#  conv2d_19_model_1 (Conv2D)     (None, None, None,   10240       ['block35_1_ac_model_1[0][0]']
#                                 32)
#
#  conv2d_22_model_1 (Conv2D)     (None, None, None,   13824       ['activation_21_model_1[0][0]']
#                                 48)
#
#  batch_normalization_19_model_1  (None, None, None,   96         ['conv2d_19_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_22_model_1  (None, None, None,   144        ['conv2d_22_model_1[0][0]']
#   (BatchNormalization)          48)
#
#  activation_19_model_1 (Activat  (None, None, None,   0          ['batch_normalization_19_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_22_model_1 (Activat  (None, None, None,   0          ['batch_normalization_22_model_1[
#  ion)                           48)                              0][0]']
#
#  conv2d_18_model_1 (Conv2D)     (None, None, None,   10240       ['block35_1_ac_model_1[0][0]']
#                                 32)
#
#  conv2d_20_model_1 (Conv2D)     (None, None, None,   9216        ['activation_19_model_1[0][0]']
#                                 32)
#
#  conv2d_23_model_1 (Conv2D)     (None, None, None,   27648       ['activation_22_model_1[0][0]']
#                                 64)
#
#  batch_normalization_18_model_1  (None, None, None,   96         ['conv2d_18_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_20_model_1  (None, None, None,   96         ['conv2d_20_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_23_model_1  (None, None, None,   192        ['conv2d_23_model_1[0][0]']
#   (BatchNormalization)          64)
#
#  activation_18_model_1 (Activat  (None, None, None,   0          ['batch_normalization_18_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_20_model_1 (Activat  (None, None, None,   0          ['batch_normalization_20_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_23_model_1 (Activat  (None, None, None,   0          ['batch_normalization_23_model_1[
#  ion)                           64)                              0][0]']
#
#  block35_2_mixed_model_1 (Conca  (None, None, None,   0          ['activation_18_model_1[0][0]',
#  tenate)                        128)                              'activation_20_model_1[0][0]',
#                                                                   'activation_23_model_1[0][0]']
#
#  block35_2_conv_model_1 (Conv2D  (None, None, None,   41280      ['block35_2_mixed_model_1[0][0]']
#  )                              320)
#
#  block35_2_model_1 (Lambda)     (None, None, None,   0           ['block35_1_ac_model_1[0][0]',
#                                 320)                              'block35_2_conv_model_1[0][0]']
#
#  block35_2_ac_model_1 (Activati  (None, None, None,   0          ['block35_2_model_1[0][0]']
#  on)                            320)
#
#  conv2d_27_model_1 (Conv2D)     (None, None, None,   10240       ['block35_2_ac_model_1[0][0]']
#                                 32)
#
#  batch_normalization_27_model_1  (None, None, None,   96         ['conv2d_27_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  activation_27_model_1 (Activat  (None, None, None,   0          ['batch_normalization_27_model_1[
#  ion)                           32)                              0][0]']
#
#  conv2d_25_model_1 (Conv2D)     (None, None, None,   10240       ['block35_2_ac_model_1[0][0]']
#                                 32)
#
#  conv2d_28_model_1 (Conv2D)     (None, None, None,   13824       ['activation_27_model_1[0][0]']
#                                 48)
#
#  batch_normalization_25_model_1  (None, None, None,   96         ['conv2d_25_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_28_model_1  (None, None, None,   144        ['conv2d_28_model_1[0][0]']
#   (BatchNormalization)          48)
#
#  activation_25_model_1 (Activat  (None, None, None,   0          ['batch_normalization_25_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_28_model_1 (Activat  (None, None, None,   0          ['batch_normalization_28_model_1[
#  ion)                           48)                              0][0]']
#
#  conv2d_24_model_1 (Conv2D)     (None, None, None,   10240       ['block35_2_ac_model_1[0][0]']
#                                 32)
#
#  conv2d_26_model_1 (Conv2D)     (None, None, None,   9216        ['activation_25_model_1[0][0]']
#                                 32)
#
#  conv2d_29_model_1 (Conv2D)     (None, None, None,   27648       ['activation_28_model_1[0][0]']
#                                 64)
#
#  batch_normalization_24_model_1  (None, None, None,   96         ['conv2d_24_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_26_model_1  (None, None, None,   96         ['conv2d_26_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_29_model_1  (None, None, None,   192        ['conv2d_29_model_1[0][0]']
#   (BatchNormalization)          64)
#
#  activation_24_model_1 (Activat  (None, None, None,   0          ['batch_normalization_24_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_26_model_1 (Activat  (None, None, None,   0          ['batch_normalization_26_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_29_model_1 (Activat  (None, None, None,   0          ['batch_normalization_29_model_1[
#  ion)                           64)                              0][0]']
#
#  block35_3_mixed_model_1 (Conca  (None, None, None,   0          ['activation_24_model_1[0][0]',
#  tenate)                        128)                              'activation_26_model_1[0][0]',
#                                                                   'activation_29_model_1[0][0]']
#
#  block35_3_conv_model_1 (Conv2D  (None, None, None,   41280      ['block35_3_mixed_model_1[0][0]']
#  )                              320)
#
#  block35_3_model_1 (Lambda)     (None, None, None,   0           ['block35_2_ac_model_1[0][0]',
#                                 320)                              'block35_3_conv_model_1[0][0]']
#
#  block35_3_ac_model_1 (Activati  (None, None, None,   0          ['block35_3_model_1[0][0]']
#  on)                            320)
#
#  conv2d_33_model_1 (Conv2D)     (None, None, None,   10240       ['block35_3_ac_model_1[0][0]']
#                                 32)
#
#  batch_normalization_33_model_1  (None, None, None,   96         ['conv2d_33_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  activation_33_model_1 (Activat  (None, None, None,   0          ['batch_normalization_33_model_1[
#  ion)                           32)                              0][0]']
#
#  conv2d_31_model_1 (Conv2D)     (None, None, None,   10240       ['block35_3_ac_model_1[0][0]']
#                                 32)
#
#  conv2d_34_model_1 (Conv2D)     (None, None, None,   13824       ['activation_33_model_1[0][0]']
#                                 48)
#
#  batch_normalization_31_model_1  (None, None, None,   96         ['conv2d_31_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_34_model_1  (None, None, None,   144        ['conv2d_34_model_1[0][0]']
#   (BatchNormalization)          48)
#
#  activation_31_model_1 (Activat  (None, None, None,   0          ['batch_normalization_31_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_34_model_1 (Activat  (None, None, None,   0          ['batch_normalization_34_model_1[
#  ion)                           48)                              0][0]']
#
#  conv2d_30_model_1 (Conv2D)     (None, None, None,   10240       ['block35_3_ac_model_1[0][0]']
#                                 32)
#
#  conv2d_32_model_1 (Conv2D)     (None, None, None,   9216        ['activation_31_model_1[0][0]']
#                                 32)
#
#  conv2d_35_model_1 (Conv2D)     (None, None, None,   27648       ['activation_34_model_1[0][0]']
#                                 64)
#
#  batch_normalization_30_model_1  (None, None, None,   96         ['conv2d_30_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_32_model_1  (None, None, None,   96         ['conv2d_32_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_35_model_1  (None, None, None,   192        ['conv2d_35_model_1[0][0]']
#   (BatchNormalization)          64)
#
#  activation_30_model_1 (Activat  (None, None, None,   0          ['batch_normalization_30_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_32_model_1 (Activat  (None, None, None,   0          ['batch_normalization_32_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_35_model_1 (Activat  (None, None, None,   0          ['batch_normalization_35_model_1[
#  ion)                           64)                              0][0]']
#
#  block35_4_mixed_model_1 (Conca  (None, None, None,   0          ['activation_30_model_1[0][0]',
#  tenate)                        128)                              'activation_32_model_1[0][0]',
#                                                                   'activation_35_model_1[0][0]']
#
#  block35_4_conv_model_1 (Conv2D  (None, None, None,   41280      ['block35_4_mixed_model_1[0][0]']
#  )                              320)
#
#  block35_4_model_1 (Lambda)     (None, None, None,   0           ['block35_3_ac_model_1[0][0]',
#                                 320)                              'block35_4_conv_model_1[0][0]']
#
#  block35_4_ac_model_1 (Activati  (None, None, None,   0          ['block35_4_model_1[0][0]']
#  on)                            320)
#
#  conv2d_39_model_1 (Conv2D)     (None, None, None,   10240       ['block35_4_ac_model_1[0][0]']
#                                 32)
#
#  batch_normalization_39_model_1  (None, None, None,   96         ['conv2d_39_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  activation_39_model_1 (Activat  (None, None, None,   0          ['batch_normalization_39_model_1[
#  ion)                           32)                              0][0]']
#
#  conv2d_37_model_1 (Conv2D)     (None, None, None,   10240       ['block35_4_ac_model_1[0][0]']
#                                 32)
#
#  conv2d_40_model_1 (Conv2D)     (None, None, None,   13824       ['activation_39_model_1[0][0]']
#                                 48)
#
#  batch_normalization_37_model_1  (None, None, None,   96         ['conv2d_37_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_40_model_1  (None, None, None,   144        ['conv2d_40_model_1[0][0]']
#   (BatchNormalization)          48)
#
#  activation_37_model_1 (Activat  (None, None, None,   0          ['batch_normalization_37_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_40_model_1 (Activat  (None, None, None,   0          ['batch_normalization_40_model_1[
#  ion)                           48)                              0][0]']
#
#  conv2d_36_model_1 (Conv2D)     (None, None, None,   10240       ['block35_4_ac_model_1[0][0]']
#                                 32)
#
#  conv2d_38_model_1 (Conv2D)     (None, None, None,   9216        ['activation_37_model_1[0][0]']
#                                 32)
#
#  conv2d_41_model_1 (Conv2D)     (None, None, None,   27648       ['activation_40_model_1[0][0]']
#                                 64)
#
#  batch_normalization_36_model_1  (None, None, None,   96         ['conv2d_36_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_38_model_1  (None, None, None,   96         ['conv2d_38_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  batch_normalization_41_model_1  (None, None, None,   192        ['conv2d_41_model_1[0][0]']
#   (BatchNormalization)          64)
#
#  activation_36_model_1 (Activat  (None, None, None,   0          ['batch_normalization_36_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_38_model_1 (Activat  (None, None, None,   0          ['batch_normalization_38_model_1[
#  ion)                           32)                              0][0]']
#
#  activation_41_model_1 (Activat  (None, None, None,   0          ['batch_normalization_41_model_1[
#  ion)                           64)                              0][0]']
#
#  block35_5_mixed_model_1 (Conca  (None, None, None,   0          ['activation_36_model_1[0][0]',
#  tenate)                        128)                              'activation_38_model_1[0][0]',
#                                                                   'activation_41_model_1[0][0]']
#
#  block35_5_conv_model_1 (Conv2D  (None, None, None,   41280      ['block35_5_mixed_model_1[0][0]']
#  )                              320)
#
#  block35_5_model_1 (Lambda)     (None, None, None,   0           ['block35_4_ac_model_1[0][0]',
#                                 320)                              'block35_5_conv_model_1[0][0]']
#
#  block35_5_ac_model_1 (Activati  (None, None, None,   0          ['block35_5_model_1[0][0]']
#  on)                            320)
#
#  conv2d_45_model_1 (Conv2D)     (None, None, None,   10240       ['block35_5_ac_model_1[0][0]']
#                                 32)
#
#  batch_normalization_45_model_1  (None, None, None,   96         ['conv2d_45_model_1[0][0]']
#   (BatchNormalization)          32)
#
#  activation_45_model_1 (Activat  (None, None, None,   0          ['batch_normalization_45_model_1[
#  ion)                           32)                              0][0]']
#
#  conv2d_43_model_1 (Conv2D)     (None, None, None,   10240       ['block35_5_ac_model_1[0][0]']
#                                 32)
#
#  conv2d_46_model_1 (Conv2D)     (None, None, None,   13824       ['activation_45_model_1[0][0]']
#                                 48)
#
# ...
#  vation)                        2048)                            ]
#
#  block8_9_mixed_model_1 (Concat  (None, None, None,   0          ['activation_195_model_1[0][0]',
#  enate)                         448)                              'activation_198_model_1[0][0]']
#
#  conv5_block2_1_conv_model_2 (C  (None, None, None,   1049088    ['conv5_block1_out_model_2[0][0]'
#  onv2D)                         512)                             ]
#
#  block8_9_conv_model_1 (Conv2D)  (None, None, None,   933920     ['block8_9_mixed_model_1[0][0]']
#                                 2080)
#
#  conv5_block2_1_bn_model_2 (Bat  (None, None, None,   2048       ['conv5_block2_1_conv_model_2[0][
#  chNormalization)               512)                             0]']
#
#  block8_9_model_1 (Lambda)      (None, None, None,   0           ['block8_8_ac_model_1[0][0]',
#                                 2080)                             'block8_9_conv_model_1[0][0]']
#
#  conv5_block2_1_relu_model_2 (A  (None, None, None,   0          ['conv5_block2_1_bn_model_2[0][0]
#  ctivation)                     512)                             ']
#
#  block8_9_ac_model_1 (Activatio  (None, None, None,   0          ['block8_9_model_1[0][0]']
#  n)                             2080)
#
#  conv5_block2_2_conv_model_2 (C  (None, None, None,   2359808    ['conv5_block2_1_relu_model_2[0][
#  onv2D)                         512)                             0]']
#
#  conv2d_200_model_1 (Conv2D)    (None, None, None,   399360      ['block8_9_ac_model_1[0][0]']
#                                 192)
#
#  conv5_block2_2_bn_model_2 (Bat  (None, None, None,   2048       ['conv5_block2_2_conv_model_2[0][
#  chNormalization)               512)                             0]']
#
#  batch_normalization_200_model_  (None, None, None,   576        ['conv2d_200_model_1[0][0]']
#  1 (BatchNormalization)         192)
#
#  conv5_block2_2_relu_model_2 (A  (None, None, None,   0          ['conv5_block2_2_bn_model_2[0][0]
#  ctivation)                     512)                             ']
#
#  activation_200_model_1 (Activa  (None, None, None,   0          ['batch_normalization_200_model_1
#  tion)                          192)                             [0][0]']
#
#  conv5_block2_3_conv_model_2 (C  (None, None, None,   1050624    ['conv5_block2_2_relu_model_2[0][
#  onv2D)                         2048)                            0]']
#
#  conv2d_201_model_1 (Conv2D)    (None, None, None,   129024      ['activation_200_model_1[0][0]']
#                                 224)
#
#  conv5_block2_3_bn_model_2 (Bat  (None, None, None,   8192       ['conv5_block2_3_conv_model_2[0][
#  chNormalization)               2048)                            0]']
#
#  batch_normalization_201_model_  (None, None, None,   672        ['conv2d_201_model_1[0][0]']
#  1 (BatchNormalization)         224)
#
#  conv5_block2_add_model_2 (Add)  (None, None, None,   0          ['conv5_block1_out_model_2[0][0]'
#                                 2048)                            , 'conv5_block2_3_bn_model_2[0][0
#                                                                  ]']
#
#  activation_201_model_1 (Activa  (None, None, None,   0          ['batch_normalization_201_model_1
#  tion)                          224)                             [0][0]']
#
#  conv5_block2_out_model_2 (Acti  (None, None, None,   0          ['conv5_block2_add_model_2[0][0]'
#  vation)                        2048)                            ]
#
#  conv2d_199_model_1 (Conv2D)    (None, None, None,   399360      ['block8_9_ac_model_1[0][0]']
#                                 192)
#
#  conv2d_202_model_1 (Conv2D)    (None, None, None,   172032      ['activation_201_model_1[0][0]']
#                                 256)
#
#  conv5_block3_1_conv_model_2 (C  (None, None, None,   1049088    ['conv5_block2_out_model_2[0][0]'
#  onv2D)                         512)                             ]
#
#  batch_normalization_199_model_  (None, None, None,   576        ['conv2d_199_model_1[0][0]']
#  1 (BatchNormalization)         192)
#
#  batch_normalization_202_model_  (None, None, None,   768        ['conv2d_202_model_1[0][0]']
#  1 (BatchNormalization)         256)
#
#  conv5_block3_1_bn_model_2 (Bat  (None, None, None,   2048       ['conv5_block3_1_conv_model_2[0][
#  chNormalization)               512)                             0]']
#
#  activation_199_model_1 (Activa  (None, None, None,   0          ['batch_normalization_199_model_1
#  tion)                          192)                             [0][0]']
#
#  activation_202_model_1 (Activa  (None, None, None,   0          ['batch_normalization_202_model_1
#  tion)                          256)                             [0][0]']
#
#  conv5_block3_1_relu_model_2 (A  (None, None, None,   0          ['conv5_block3_1_bn_model_2[0][0]
#  ctivation)                     512)                             ']
#
#  block8_10_mixed_model_1 (Conca  (None, None, None,   0          ['activation_199_model_1[0][0]',
#  tenate)                        448)                              'activation_202_model_1[0][0]']
#
#  conv5_block3_2_conv_model_2 (C  (None, None, None,   2359808    ['conv5_block3_1_relu_model_2[0][
#  onv2D)                         512)                             0]']
#
#  block8_10_conv_model_1 (Conv2D  (None, None, None,   933920     ['block8_10_mixed_model_1[0][0]']
#  )                              2080)
#
#  conv5_block3_2_bn_model_2 (Bat  (None, None, None,   2048       ['conv5_block3_2_conv_model_2[0][
#  chNormalization)               512)                             0]']
#
#  block8_10_model_1 (Lambda)     (None, None, None,   0           ['block8_9_ac_model_1[0][0]',
#                                 2080)                             'block8_10_conv_model_1[0][0]']
#
#  conv5_block3_2_relu_model_2 (A  (None, None, None,   0          ['conv5_block3_2_bn_model_2[0][0]
#  ctivation)                     512)                             ']
#
#  conv_7b_model_1 (Conv2D)       (None, None, None,   3194880     ['block8_10_model_1[0][0]']
#                                 1536)
#
#  conv5_block3_3_conv_model_2 (C  (None, None, None,   1050624    ['conv5_block3_2_relu_model_2[0][
#  onv2D)                         2048)                            0]']
#
#  conv_7b_bn_model_1 (BatchNorma  (None, None, None,   4608       ['conv_7b_model_1[0][0]']
#  lization)                      1536)
#
#  conv5_block3_3_bn_model_2 (Bat  (None, None, None,   8192       ['conv5_block3_3_conv_model_2[0][
#  chNormalization)               2048)                            0]']
#
#  conv_7b_ac_model_1 (Activation  (None, None, None,   0          ['conv_7b_bn_model_1[0][0]']
#  )                              1536)
#
#  conv5_block3_add_model_2 (Add)  (None, None, None,   0          ['conv5_block2_out_model_2[0][0]'
#                                 2048)                            , 'conv5_block3_3_bn_model_2[0][0
#                                                                  ]']
#
#  zero_padding2d (ZeroPadding2D)  (None, None, None,   0          ['conv_7b_ac_model_1[0][0]']
#                                 1536)
#
#  conv5_block3_out_model_2 (Acti  (None, None, None,   0          ['conv5_block3_add_model_2[0][0]'
#  vation)                        2048)                            ]
#
#  concatenate (Concatenate)      (None, None, None,   0           ['zero_padding2d[0][0]',
#                                 3584)                             'conv5_block3_out_model_2[0][0]'
#                                                                  ]
#
#  global_average_pooling2d (Glob  (None, 3584)        0           ['concatenate[0][0]']
#  alAveragePooling2D)
#
#  flatten (Flatten)              (None, 3584)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 3584)         0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 28)           100380      ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 3584)         103936      ['dense[0][0]']
#
#  multiply (Multiply)            (None, None, None,   0           ['concatenate[0][0]',
#                                 3584)                             'dense_1[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 3584)        0           ['multiply[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 14)           50190       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 78,178,954
# Trainable params: 78,065,290
# Non-trainable params: 113,664
# __________________________________________________________________________________________________

# %% [markdown]
# ##Train the model for labelled data

# %%
start = time.time()

model_train = model.fit(
        dataset["train"],
        steps_per_epoch = STEPS_TRAIN,
        epochs = 20,
        validation_data = dataset["val"],
        validation_steps = STEPS_VAL,
        validation_freq = 1,
        verbose = 1
)

print ("Total time:", (np.round(time.time() - start, 4)/60), "minutes.")
# Out:
# Epoch 1/20
# 4132/4132 [==============================] - 749s 160ms/step - loss: 0.9429 - sparse_categorical_accuracy: 0.6883 - val_loss: 2.3718 - val_sparse_categorical_accuracy: 0.5931
# Epoch 2/20
# 4132/4132 [==============================] - 634s 153ms/step - loss: 0.4808 - sparse_categorical_accuracy: 0.8387 - val_loss: 0.8702 - val_sparse_categorical_accuracy: 0.6679
# Epoch 3/20
# 4132/4132 [==============================] - 633s 153ms/step - loss: 0.3461 - sparse_categorical_accuracy: 0.8854 - val_loss: 0.5805 - val_sparse_categorical_accuracy: 0.7879
# Epoch 4/20
# 4132/4132 [==============================] - 632s 153ms/step - loss: 0.2708 - sparse_categorical_accuracy: 0.9108 - val_loss: 1.4750 - val_sparse_categorical_accuracy: 0.6115
# Epoch 5/20
# 4132/4132 [==============================] - 632s 153ms/step - loss: 0.2172 - sparse_categorical_accuracy: 0.9284 - val_loss: 0.6204 - val_sparse_categorical_accuracy: 0.7965
# Epoch 6/20
# 4132/4132 [==============================] - 633s 153ms/step - loss: 0.1932 - sparse_categorical_accuracy: 0.9358 - val_loss: 0.5090 - val_sparse_categorical_accuracy: 0.8395
# Epoch 7/20
# 4132/4132 [==============================] - 632s 153ms/step - loss: 0.1671 - sparse_categorical_accuracy: 0.9438 - val_loss: 0.4567 - val_sparse_categorical_accuracy: 0.8877
# Epoch 8/20
# 4132/4132 [==============================] - 632s 153ms/step - loss: 0.1514 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.4777 - val_sparse_categorical_accuracy: 0.8424
# Epoch 9/20
# 4132/4132 [==============================] - 632s 153ms/step - loss: 0.1347 - sparse_categorical_accuracy: 0.9548 - val_loss: 0.3689 - val_sparse_categorical_accuracy: 0.8864
# Epoch 10/20
# 4132/4132 [==============================] - 632s 153ms/step - loss: 0.1323 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.3254 - val_sparse_categorical_accuracy: 0.9021
# Epoch 11/20
# 4132/4132 [==============================] - 634s 153ms/step - loss: 0.1136 - sparse_categorical_accuracy: 0.9620 - val_loss: 0.2195 - val_sparse_categorical_accuracy: 0.9209
# Epoch 12/20
# 4132/4132 [==============================] - 631s 153ms/step - loss: 0.1085 - sparse_categorical_accuracy: 0.9634 - val_loss: 0.2761 - val_sparse_categorical_accuracy: 0.9169
# Epoch 13/20
# 4132/4132 [==============================] - 631s 153ms/step - loss: 0.1010 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.3718 - val_sparse_categorical_accuracy: 0.8887
# Epoch 14/20
# 4132/4132 [==============================] - 631s 153ms/step - loss: 0.0965 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.2674 - val_sparse_categorical_accuracy: 0.9192
# Epoch 15/20
# 4132/4132 [==============================] - 631s 153ms/step - loss: 0.0924 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.2631 - val_sparse_categorical_accuracy: 0.9294
# Epoch 16/20
# 4132/4132 [==============================] - 631s 153ms/step - loss: 0.0863 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.3616 - val_sparse_categorical_accuracy: 0.9105
# Epoch 17/20
# 4132/4132 [==============================] - 631s 153ms/step - loss: 0.0765 - sparse_categorical_accuracy: 0.9741 - val_loss: 0.3057 - val_sparse_categorical_accuracy: 0.8989
# Epoch 18/20
# 4132/4132 [==============================] - 631s 153ms/step - loss: 0.0798 - sparse_categorical_accuracy: 0.9734 - val_loss: 0.2580 - val_sparse_categorical_accuracy: 0.9217
# Epoch 19/20
# 4132/4132 [==============================] - 631s 153ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.2360 - val_sparse_categorical_accuracy: 0.9330
# Epoch 20/20
# 4132/4132 [==============================] - 631s 153ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9761 - val_loss: 0.2740 - val_sparse_categorical_accuracy: 0.9211
# Total time: 212.76151666666667 minutes.

# %%
print(model_train.history.keys())
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy'])

# %%
def save_model():
  handle = open(record_dir+"/model_train.pkl", 'wb')
  pickle.dump(model_train.history, handle)
  model.save(record_dir+'/model.h5')

# %% [markdown]
# ## Model Evaluation

# %%
def calculate_true_and_predicted_cat(model, dataset):

  # Using test data to evaluate the model
  test_evaluate = model.evaluate(dataset["test"], steps=STEPS_TEST) # steps since tf.dataset
  print("\nTest Accuracy: ", test_evaluate)

  # Find true_categories and predicted_categories
  eval_dataset = dataset["test"].unbatch().take(DATASET_SIZE_TEST)
  eval_dataset = eval_dataset.as_numpy_iterator()
  eval_dataset = np.array(list(eval_dataset))
  true_categories = list(eval_dataset[:,1]) 
  eval_images = np.stack(eval_dataset[:,0], axis=0) # eval_dataset[:,0] = give me the 0th index of all the rows in eval_dataset

  # Create predictions and predicted_categories
  predictions = model.predict(eval_images)
  predicted_categories = [np.argmax(pred) for pred in predictions]

  return true_categories, predicted_categories

def using_evaluation_metrics(model_train, true_categories, predicted_categories):

    sns.set()
    
    # Plot Accuracy
    plot_accuracy(model_train)
    # Plot Loss
    plot_loss(model_train)

    print('\nAccuracy score is :', metrics.accuracy_score(true_categories, predicted_categories))
    print('Precision score is :', metrics.precision_score(true_categories, predicted_categories, average='weighted'))
    print('Recall score is :',metrics.recall_score(true_categories, predicted_categories, average='weighted'))
    print('F1 Score is :', metrics.f1_score(true_categories, predicted_categories,average='weighted'))
    print('Cohen Kappa Score :', metrics.cohen_kappa_score(true_categories, predicted_categories))
    print("MCC :", metrics.matthews_corrcoef(true_categories, predicted_categories))
    
    # Print the Classification report
    print("\nClassification Report: ")
    report = metrics.classification_report( y_true=true_categories, y_pred=predicted_categories,
                labels=range(NUMBER_CLASSES),
                target_names=CLASS_NAMES,
                digits=3,
                zero_division=0)
    print(report)

def plot_confusion_matrix(cm, names=None):

    print('Confusion Matrix')
    
    plt.figure(figsize=(20,20))

    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()

    tick_marks = np.arange(NUMBER_CLASSES)
    plt.xticks(tick_marks, CLASS_NAMES, rotation=90)
    plt.yticks(tick_marks, CLASS_NAMES)

    # normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cm = np.around(cm, decimals=2)
    cm[np.isnan(cm)] = 0.0
    print("Normalized confusion matrix")

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True Categories')
    plt.xlabel('Predicted Categories')
    plt.savefig(record_dir+"/confusion_matrix.pdf", format="pdf")
    plt.show()

def plot_accuracy(model_train):
  
  plt.plot(model_train.history['sparse_categorical_accuracy'], label='Training Accuracy')
  plt.plot(model_train.history['val_sparse_categorical_accuracy'], label='Validation Accuracy')
  plt.title('Model Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(loc='upper left')
  plt.show()

def plot_loss(model_train):
  plt.plot(model_train.history['loss'], label='Training Loss')
  plt.plot(model_train.history['val_loss'], label='Validation Loss')
  plt.title('Model Loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(loc='upper left')
  plt.show()

# %%
true_categories, predicted_categories = calculate_true_and_predicted_cat(model, dataset)
print(true_categories)
print(predicted_categories)
using_evaluation_metrics(model_train, true_categories, predicted_categories)

# Plot the Confusion Matrix
cm = metrics.confusion_matrix(true_categories, predicted_categories)
plot_confusion_matrix(cm, CLASS_NAMES)

save_model()
# Out:
# 1180/1180 [==============================] - 67s 54ms/step - loss: 0.2488 - sparse_categorical_accuracy: 0.9222
#
# Test Accuracy:  [0.24884136021137238, 0.9222457408905029]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   # Remove the CWD from sys.path while we load stuff.
# [12, 12, 12, 12, 12, 12, 12, 12, 7, 12, 10, 12, 10, 12, 12, 12, 12, 12, 9, 12, 10, 12, 12, 0, 12, 7, 12, 10, 12, 7, 12, 7, 12, 7, 12, 10, 12, 12, 12, 12, 12, 8, 12, 12, 8, 12, 12, 10, 12, 7, 12, 12, 7, 3, 6, 3, 12, 12, 12, 7, 12, 12, 12, 12, 12, 8, 12, 7, 7, 12, 12, 12, 12, 12, 12, 7, 12, 7, 12, 12, 10, 7, 12, 1, 12, 3, 12, 12, 12, 9, 12, 8, 12, 12, 7, 12, 7, 12, 12, 12, 7, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 10, 12, 12, 12, 0, 12, 12, 12, 12, 10, 12, 7, 6, 3, 12, 2, 12, 3, 3, 12, 12, 12, 12, 3, 12, 12, 12, 10, 12, 7, 12, 12, 2, 7, 12, 12, 10, 12, 7, 12, 12, 12, 12, 10, 8, 12, 7, 10, 12, 7, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12,